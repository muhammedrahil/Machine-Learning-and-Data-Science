# %%
import pandas as pd
df = pd.read_csv('employee.csv')
df
# Out:
#    employee       dept   age     salary
# 0         A         HR  18.0    30000.0
# 1         B         HR  18.0    33000.0
# 2         C         HR  22.0    40000.0
# 3         D         HR  23.0    30000.0
# 4         E      SALES  18.0    34300.0
# 5         F      SALES  20.0    23333.0
# 6         G      SALES   NaN    56666.0
# 7         H        NaN  30.0    45555.0
# 8         I      SALES  33.0    34343.0
# 9         J      SALES   NaN    34343.0
# 10        K  DEVELOPER  34.0    65445.0
# 11        L  DEVELOPER  29.0        NaN
# 12        M  DEVELOPER  33.0    34343.0
# 13        N        NaN  24.0    23232.0
# 14        O  DEVELOPER   NaN   122343.0
# 15        P         QA  40.0    23234.0
# 16        Q         QA  23.0        NaN
# 17        R         QA  56.0    56556.0
# 18        S         QA  45.0     6563.0
# 19        T         QA  34.0   234342.0
# 20        U        NaN   NaN   243543.0
# 21        V        CEO  55.0  5465656.0
# ...

# %%
df['dept']
