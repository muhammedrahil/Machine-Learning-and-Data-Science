# %%
import pandas as pd

dataset = pd.read_csv('large_min_max_temp_dataset.csv')

# %%
print(dataset.shape)
# Out:
# (1000, 5)

# %%
print(dataset.describe())
# Out:
#        Min Temp (°C)  Max Temp (°C)
# count    1000.000000    1000.000000
# mean        2.913000      15.597000
# std         7.457415       8.878255
# min       -10.000000      -5.000000
# 25%        -3.000000       9.000000
# 50%         3.000000      15.000000
# 75%         9.000000      23.000000
# max        15.000000      35.000000

# %%
dataset = dataset.rename(columns={
    'Min Temp (°C)': 'min_temp',
    'Max Temp (°C)': 'max_temp',
})

# %%
dataset.plot(x='min_temp',y='max_temp',style='o')
# Out:
# <Axes: xlabel='min_temp'>

# %%
import matplotlib.pyplot as plt

plt.title("Min vs Max Temperature")
# Out:
# Text(0.5, 1.0, 'Min vs Max Temperature')

# %%
plt.xlabel('Min Temperature')
plt.ylabel('Max Temperature')
# Out:
# Text(0, 0.5, 'Max Temperature')

# %%
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.tight_layout()

# %%
import seaborn as seaborninstance

seaborninstance.displot(x=dataset['min_temp'])

# %%
x = dataset['min_temp'].values.reshape(-1,1)
y = dataset['max_temp'].values.reshape(-1,1)

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(x,y, test_size=0.2, random_state=0)

# %%
from sklearn.linear_model import LinearRegression
regression = LinearRegression()
regression.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print(regression.intercept_)
# Out:
# [12.69175346]

# %%
print(regression.coef_)
# Out:
# [[1.00117363]]

# %%
y_pred = regression.predict(x_test)

# %%
y_pred
# Out:
# array([[ 4.68236444],
#        [11.69057983],
#        [14.69410071],
#        [21.70231609],
#        [10.6894062 ],
#        [ 2.68001719],
#        [27.70935785],
#        [15.69527434],
#        [24.70583697],
#        [ 2.68001719],
#        [22.70348972],
#        [ 7.68588532],
#        [11.69057983],
#        [26.70818423],
#        [21.70231609],
#        [19.69996884],
#        [25.7070106 ],
#        [19.69996884],
#        [ 5.68353807],
#        [ 2.68001719],
#        [17.69762159],
#        [11.69057983],
#        [17.69762159],
#        [24.70583697],
#        [24.70583697],
#        [ 4.68236444],
#        [15.69527434],
#        [ 6.6847117 ],
#        [14.69410071],
#        [15.69527434],
#        [23.70466335],
#        [25.7070106 ],
#        [15.69527434],
#        [ 6.6847117 ],
#        [ 7.68588532],
#        [12.69175346],
#        [27.70935785],
#        [17.69762159],
#        [20.70114247],
#        [14.69410071],
#        [20.70114247],
# ...

# %%
y_test.flatten()
# Out:
# array([ 6,  6, 13, 28,  3,  2, 31, 10, 17,  3, 28,  8, 15, 30, 23, 12, 31,
#        16,  8,  9, 13, 10, 17, 31, 31,  8,  8,  0, 15, 14, 18, 19, 10, 12,
#         3, 20, 25, 11, 17, 22, 17, 14, 23, 17, 14, 24, 26, 15, -1, 13,  4,
#        27, 26, 15, 32, 18,  9,  1, 10, 28, 24, 14,  3, 26, 17, 26,  1, 12,
#        18,  6, 34, 24, 19, 15, 12,  6,  5, 30, 23,  5, 14, 15, 12,  3, 19,
#        12, -3, 26, 31,  6,  8, 16,  6, 12, 34,  9, 23, 19, 34, 26, 13, 16,
#        15, 31,  4, 20, 13,  7,  5,  5,  8, 33,  7, 29, 14, 11, 12, 31, 13,
#        22, 25, 18, 25, 21, 22, 12, 26,  5,  1, 22, 23, 26, 25, 16, 23, 28,
#        30,  8, 34, 22, 25, 13, 28, 27, 17, 11,  0, 22, 13, 15, 15, 18, 24,
#        15, -1, 15, 19, 15, 21, 20, 23, 11,  0, 21, 22, 13, 27, 13, 19, 12,
#         7, 21, 18, 27,  4, -5,  0, 19,  9, 11, 13, 13, 28, -1,  9,  3, 10,
#        35, 22, 25,  5, 27, 16, 16,  2, 27, 25, 21, 12, 18])

# %%
df = pd.DataFrame({"actual_value": y_test.flatten(), "expected_value": y_pred.flatten()})

# %%
df
# Out:
#      actual_value  expected_value
# 0               6        4.682364
# 1               6       11.690580
# 2              13       14.694101
# 3              28       21.702316
# 4               3       10.689406
# ..            ...             ...
# 195            27       19.699969
# 196            25       22.703490
# 197            21       24.705837
# 198            12       11.690580
# 199            18       15.695274
#
# [200 rows x 2 columns]

# %%
df1 = df.head(25)

# %%
df1.plot(kind='bar',figsize=(16,10))
# Out:
# <Axes: >

# %%
plt.grid(which='major',linestyle='-',linewidth='0.5',color='green')

# %%
plt.grid(which='minor',linestyle=':',linewidth='0.5',color='black')

# %%
plt.scatter(x_test,y_test,color='gray')

# %%
plt.plot(x_test,y_pred,color='red',linewidth=2)

# %%
plt.grid(which='major',linestyle='-',linewidth='0.5',color='green')
plt.grid(which='minor',linestyle=':',linewidth='0.5',color='black')
plt.scatter(x_test,y_test,color='gray')
plt.plot(x_test,y_pred,color='red',linewidth=2)
plt.show()

# %%
from sklearn import metrics

metrics.mean_absolute_error(y_test, y_pred)
# Out:
# 4.198695791869144

# %%
metrics.mean_squared_error(y_test, y_pred)
# Out:
# 22.978034571267823

# %%
import numpy as np
np.sqrt(metrics.mean_squared_error(y_test, y_pred))
# Out:
# np.float64(4.793540922039554)
